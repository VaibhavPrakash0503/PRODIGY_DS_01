# %% [markdown]
# ## Importing libraries and the dataset

# %%
import pandas as pd

#Reading the data set
df = pd.read_csv("data.csv")

#Removing the unnecessary values
df = df.drop(columns=["Indicator Name", "Indicator Code", "Country Name"])

# %% [markdown]
# ## Info about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  266 non-null    object
#  1   1960          264 non-null    float64
#  2   1961          264 non-null    float64
#  3   1962          264 non-null    float64
#  4   1963          264 non-null    float64
#  5   1964          264 non-null    float64
#  6   1965          264 non-null    float64
#  7   1966          264 non-null    float64
#  8   1967          264 non-null    float64
#  9   1968          264 non-null    float64
#  10  1969          264 non-null    float64
#  11  1970          264 non-null    float64
#  12  1971          264 non-null    float64
#  13  1972          264 non-null    float64
#  14  1973          264 non-null    float64
#  15  1974          264 non-null    float64
#  16  1975          264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154482e+08  1.170540e+08  1.192163e+08  1.218881e+08  1.245838e+08
# std    3.626524e+08  3.671661e+08  3.738304e+08  3.824609e+08  3.911398e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.273114e+08  1.301584e+08  1.330130e+08  1.359428e+08  1.389708e+08
# ...

# %%
#1st 5 rows for the understanding of the dataset

df.head()
# Out:
#   Country Code         1960         1961         1962         1963  \
# 0          ABW      54922.0      55578.0      56320.0      57002.0
# 1          AFE  130072080.0  133534923.0  137171659.0  140945536.0
# 2          AFG    9035043.0    9214083.0    9404406.0    9604487.0
# 3          AFW   97630925.0   99706674.0  101854756.0  104089175.0
# 4          AGO    5231654.0    5301583.0    5354310.0    5408320.0
#
#           1964         1965         1966         1967         1968  ...  \
# 0      57619.0      58190.0      58694.0      58990.0      59069.0  ...
# 1  144904094.0  149033472.0  153281203.0  157704381.0  162329396.0  ...
# 2    9814318.0   10036008.0   10266395.0   10505959.0   10756922.0  ...
# 3  106388440.0  108772632.0  111246953.0  113795019.0  116444636.0  ...
# 4    5464187.0    5521981.0    5581386.0    5641807.0    5702699.0  ...
#
#           2014         2015         2016         2017         2018  \
# ...

# %% [markdown]
# # Checking for duplicate and missing values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Country Code    0
# 1960            2
# 1961            2
# 1962            2
# 1963            2
#                ..
# 2019            1
# 2020            1
# 2021            1
# 2022            1
# 2023            1
# Length: 65, dtype: int64

# %% [markdown]
# # Removing the missing values

# %%
df = df.fillna(0)

# %%
df.isna().sum()
# Out:
# Country Code    0
# 1960            0
# 1961            0
# 1962            0
# 1963            0
#                ..
# 2019            0
# 2020            0
# 2021            0
# 2022            0
# 2023            0
# Length: 65, dtype: int64

# %% [markdown]
# ## Countries Based on total population

# %%
sorted_population = df.sort_values(by='2023',ascending=False)

# Removing the population count of continent and the sub-continent
sorted_population=sorted_population[15:]

# print("Top 10 countires of highest population")
top_10_count = sorted_population.head(10)
print(top_10_count["Country Code"])
# Out:
# 109    IND
# 40     CHN
# 95     HIC
# 181    OED
# 107    IDX
# 241    TSS
# 217    SSF
# 215    SSA
# 135    LDC
# 198    PST
# Name: Country Code, dtype: object

# %% [markdown]
# ## Bar Chart of Top 5 countries

# %%
import matplotlib.pyplot as plt

#Top ten Countries for year 2023
top_10_count.plot(x="Country Code", y = "2023", kind = "bar", figsize=(8,5),color = "skyblue")
plt.title("Population Trends of top 10 Countries")
plt.xlabel("Country Code")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# ## Line Chart of Population of countries over the year

# %%
top_10_count.set_index("Country Code",inplace=True)
top_10_count.loc[["IND","CHN"]].T.plot(kind="line",figsize=(10,6),color=["orange","red","blue"])

plt.title("Population trend in India and China over the years")
plt.xlabel("Year")
plt.ylabel("Population")
plt.grid(True)
plt.legend(title="Country")
plt.show()

# %% [markdown]
# ## Area Plot of population of India

# %%
top_10_count.loc["IND"].plot(kind="area",figsize=(10,6),color="skyblue")

plt.title("Population of India over the years")
plt.xlabel("Year")
plt.ylabel("Poupulation")
plt.show()

# %% [markdown]
# ## Population Comparison in year 2023

# %%
country = top_10_count.loc[["IND","CHN"],"2023"]

country.plot(kind="bar",figsize=(10,6), color=["orange","red"],width=0.4)

plt.title("Population comparison in year 2023")
plt.xlabel("Country")
plt.ylabel("Population")
plt.show()
